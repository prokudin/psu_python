# %%
from game1 import *  

def hangman(secretWord):
    '''
    secretWord: string, the secret word to guess.

    Starts up an interactive game of Hangman.

    * At the start of the game, let the user know how many 
      letters the secretWord contains.

    * Ask the user to supply one guess (i.e. letter) per round.

    * The user should receive feedback immediately after each guess 
      about whether their guess appears in the computers word.

    * After each round, you should also display to the user the 
      partially guessed word so far, as well as letters that the 
      user has not yet guessed.

    Follows the other limitations detailed in the problem write-up.
    '''
    # FILL IN YOUR CODE HERE...
    print("Welcome to the game, Hangman!")
    print("I am thinking of a word that is " + str(len(secretWord)) + " letters long. ")
    mistakesMade = 0
    lettersGuessed = []
    goodGuess=0
    
    maxTries = 8
    
    def inputLetter():
        done = False
        letter = ''
        while not done:
            letter = raw_input("Please, guess a letter: ").lower()
            if letter.isalpha() and len(letter) == 1:
                done = True
                return letter 
                
        
    
    while mistakesMade < maxTries and goodGuess < len(secretWord):
        print("-------------")
        print(" You have " + str(maxTries-mistakesMade)+ " left")
        print(" Available letters: " + str(getAvailableLetters(lettersGuessed)))
        
        guess = inputLetter()
        
        if guess in lettersGuessed:
            print("Oops! You've already guessed that letter: ")
            mistakesMade += 1
        elif guess in secretWord:
            print("Good guess: ")
            lettersGuessed += guess
            goodGuess += 1
        else:
            print("Oops! That letter is not in my word:")
            lettersGuessed += guess
            mistakesMade += 1
        print(str(getGuessedWord(secretWord, lettersGuessed)))
        print("-------------")

    if goodGuess == len(secretWord):
        print("Congratulations, you won!")
    else:    
        print("Sorry, you ran out of guesses. The word was" + str(secretWord))
        
secretWord = 'secret'
run = hangman(secretWord)
# Out:
# Welcome to the game, Hangman!
# I am thinking of a word that is 6 letters long.
# -------------
#  You have 8 left
#  Available letters: abcdefghijklmnopqrstuvwxyz
# Please, guess a letter: s
# Good guess:
# s _  _  _  _  _
# -------------
# -------------
#  You have 8 left
#  Available letters: abcdefghijklmnopqrtuvwxyz
# Please, guess a letter: e
# Good guess:
# se _  _ e _
# -------------
# -------------
#  You have 8 left
#  Available letters: abcdfghijklmnopqrtuvwxyz
# Please, guess a letter: c
# Good guess:
# sec _ e _
# -------------
# -------------
#  You have 8 left
#  Available letters: abdfghijklmnopqrtuvwxyz
# Please, guess a letter: r
# Good guess:
# secre _
# -------------
# -------------
#  You have 8 left
#  Available letters: abdfghijklmnopqtuvwxyz
# Please, guess a letter: r
# Oops! You've already guessed that letter:
# secre _
# -------------
# -------------
#  You have 7 left
#  Available letters: abdfghijklmnopqtuvwxyz
# Please, guess a letter: t
# Good guess:
# secret
# -------------
# -------------
#  You have 7 left
#  Available letters: abdfghijklmnopquvwxyz
