# %%
from game1 import *  

def hangman(secretWord):
    '''
    secretWord: string, the secret word to guess.

    Starts up an interactive game of Hangman.

    * At the start of the game, let the user know how many 
      letters the secretWord contains.

    * Ask the user to supply one guess (i.e. letter) per round.

    * The user should receive feedback immediately after each guess 
      about whether their guess appears in the computers word.

    * After each round, you should also display to the user the 
      partially guessed word so far, as well as letters that the 
      user has not yet guessed.

    Follows the other limitations detailed in the problem write-up.
    '''
    print('Welcome to Hangman!\nI am thinking of a word that is ' + str(len(secretWord)) + ' letters long.')
    
    wrong = 8
    lettersGuessed = []
    state = False
    
    while not state or wrong > 0:
        
        if wrong > 0:
            print('----------------------\nYou have ' + str(wrong) + ' guesses left.')
            print('letters available:' + getAvailableLetters(lettersGuessed))
            guess = raw_input('Please guess a letter: ')
            guess = guess.lower()
            
        else:
            print('----GAME OVER----\nYou ran out of guesses. The secret word was "' + secretWord + '"')
            break
        
        
        if guess in lettersGuessed:
            print('Oops! You already guessed "' + guess + '", try another letter.')
            print(getGuessedWord(secretWord, lettersGuessed))
            
        else:
            lettersGuessed.append(guess)
            state = isWordGuessed(secretWord, lettersGuessed)
            
            if state:
                print(getGuessedWord(secretWord, lettersGuessed))
                print('Congratulations, you won! The secret word was "' + secretWord +'"')
                break
                
            elif letterInWord(guess, secretWord) == False:
                print('Sorry "' + guess + '" is not in the secret word.')
                print(getGuessedWord(secretWord, lettersGuessed))
                wrong -= 1
                
            elif letterInWord(guess, secretWord) == True:
                print('Good one! ' + getGuessedWord(secretWord, lettersGuessed))

secretWord = secret
run = hangman(secretWord)
# Out:
# Welcome to Hangman!
# I am thinking of a word that is 11 letters long.
# ----------------------
# You have 8 guesses left.
# letters available:abcdefghijklmnopqrstuvwxyz
# Please guess a letter: a
# Good one! a _  _ a _  _ a _  _  _  _
# ----------------------
# You have 8 guesses left.
# letters available:bcdefghijklmnopqrstuvwxyz
# Please guess a letter: v
# Sorry "v" is not in the secret word.
# a _  _ a _  _ a _  _  _  _
# ----------------------
# You have 7 guesses left.
# letters available:bcdefghijklmnopqrstuwxyz
# Please guess a letter: b
# Sorry "b" is not in the secret word.
# a _  _ a _  _ a _  _  _  _
# ----------------------
# You have 6 guesses left.
# letters available:cdefghijklmnopqrstuwxyz
# Please guess a letter: u
# Good one! a _  _ a _  _ a _  _ u _
# ----------------------
# You have 6 guesses left.
# letters available:cdefghijklmnopqrstwxyz
# Please guess a letter: t
# Sorry "t" is not in the secret word.
# a _  _ a _  _ a _  _ u _
# ----------------------
# You have 5 guesses left.
# letters available:cdefghijklmnopqrswxyz
# Please guess a letter: h
# Good one! a _  _ a _ ha _  _ u _
# ----------------------
# You have 5 guesses left.
# letters available:cdefgijklmnopqrswxyz
# Please guess a letter: f
# Sorry "f" is not in the secret word.
# a _  _ a _ ha _  _ u _
# ----------------------
# You have 4 guesses left.
# letters available:cdegijklmnopqrswxyz
# Please guess a letter: s
# Good one! a _  _ a _ ha _  _ us
# ----------------------
# You have 4 guesses left.
# letters available:cdegijklmnopqrwxyz
# Please guess a letter: e
# Sorry "e" is not in the secret word.
# a _  _ a _ ha _  _ us
# ----------------------
# You have 3 guesses left.
# letters available:cdgijklmnopqrwxyz
# Please guess a letter: f
# Oops! You already guessed "f", try another letter.
# a _  _ a _ ha _  _ us
# ----------------------
# You have 3 guesses left.
# letters available:cdgijklmnopqrwxyz
# Please guess a letter: a
# Oops! You already guessed "a", try another letter.
# a _  _ a _ ha _  _ us
# ----------------------
# You have 3 guesses left.
# letters available:cdgijklmnopqrwxyz
# Please guess a letter: j
# Sorry "j" is not in the secret word.
# a _  _ a _ ha _  _ us
# ----------------------
# You have 2 guesses left.
# letters available:cdgiklmnopqrwxyz
# Please guess a letter: i
# Good one! a _ ia _ ha _  _ us
# ----------------------
# You have 2 guesses left.
# letters available:cdgklmnopqrwxyz
# Please guess a letter: l
# Sorry "l" is not in the secret word.
# a _ ia _ ha _  _ us
# ----------------------
# You have 1 guesses left.
# letters available:cdgkmnopqrwxyz
# Please guess a letter: o
# Good one! a _ ia _ ha _ ous
# ----------------------
# You have 1 guesses left.
# letters available:cdgkmnpqrwxyz
# Please guess a letter: g
# Sorry "g" is not in the secret word.
# a _ ia _ ha _ ous
# ----GAME OVER----
# You ran out of guesses. The secret word was "adiaphanous"
