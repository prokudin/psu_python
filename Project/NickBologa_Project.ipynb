# %%
import pandas as pd
data = pd.read_excel("1000.xlsx")
data.head()
# Out:
#    i  Ebeam         x         y         z        Q2        pT obs     value  \
# 0  0   27.6  0.037588  0.641938  0.152202  1.249727  0.110571   M  4.398481
# 1  1   27.6  0.037588  0.641938  0.154622  1.249727  0.221793   M  8.759948
# 2  2   27.6  0.037588  0.641938  0.156095  1.249727  0.327693   M  9.660459
# 3  3   27.6  0.037588  0.641938  0.159801  1.249727  0.440991   M  7.843414
# 4  4   27.6  0.037588  0.641938  0.162489  1.249727  0.581764   M  4.778433
#
#      stat_u  systrel  systabs_u  target hadron     col   F2
# 0  0.057592        0   0.350294  proton    pi+  hermes  0.0
# 1  0.071953        0   0.314397  proton    pi+  hermes  0.0
# 2  0.070699        0   0.589268  proton    pi+  hermes  0.0
# 3  0.070982        0   0.582032  proton    pi+  hermes  0.0
# 4  0.059171        0   0.319916  proton    pi+  hermes  0.0
